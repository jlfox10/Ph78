# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.signal import chirp, spectrogram


from scipy import signal
import scipy

from scipy.fft import fft, fftshift

import csv

# %%
x = []
y = []

with open('Bx1.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))
    
plt.plot(x, y)
plt.xlim([2.7, 4.3])
plt.title('Perpendicular Magnetic Field 1')
plt.xlabel('Positition')
plt.ylabel('Field Strength (G)')
plt.show()

# %%
x = []
y = []

with open('bx2.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))

    
plt.plot(x, y)
plt.xlim([2.7, 4.3])
plt.title('Perpendicular Magnetic Field 2')
plt.xlabel('Positition')
plt.ylabel('Field Strength (G)')
plt.show()

# %%
x = []
y = []

with open('ddx.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))
    
    
plt.plot(x, y)
plt.xlim([2.7, 4.3])
plt.title('dBx/dx')
plt.xlabel('Positition')
plt.ylabel('Gradient (kg/(m*s^2*A))')
plt.show()

# %%
x = []
y = []

with open('ddy.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))
    
    
plt.plot(x, y)
plt.xlim([2.7, 4.3])
plt.title('dBy/dy')
plt.xlabel('Positition')
plt.ylabel('Gradient (kg/(m*s^2*A))')
plt.show()

# %%
x = []
y = []

with open('ddz.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))
    
    
plt.plot(x, y)
plt.xlim([2.7, 4.3])
plt.title('dBz/dz')
plt.xlabel('Positition')
plt.ylabel('Gradient (kg/(m*s^2*A))')
plt.show()

# %%
x = []
y = []

with open('bxbz.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))
    
    
plt.plot(x, y)
plt.xlim([2.7, 4.3])
plt.title('dBx/dz')
plt.xlabel('Positition')
plt.ylabel('Gradient (kg/(m*s^2*A))')
plt.show()
