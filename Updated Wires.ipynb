# %%
import os
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.signal import chirp, spectrogram


from scipy import signal
import scipy

from scipy.fft import fft, fftshift

import csv

# %%
x = []
y = []

with open('editedbx.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))

xap = []
yap = []
num = 0

for i in x:
    xap.append(i)
    ind = x.index(i)
    yap.append(y[ind])
    num = num + 1

#print(xap)
start = min(xap)
end = max(xap)
print(start)
print(end)
print(num)

ave = (max(yap)-min(yap))/num
print(ave)


model = np.poly1d(np.polyfit(x, y, 2)) 

polyline = np.linspace(0, 10, 100)
plt.plot(polyline, model(polyline)) 
plt.plot(x, y)
plt.xlim([0, .7])
plt.ylim([-0.21,-0.215])
plt.title('Bx')
plt.xlabel('Positition (m)')
plt.ylabel('Field Strength (G)')
plt.show()
plt.savefig('Bx')
# Out:
# 0.0
# 0.7
# 162
# 5.38766205240694e-06

# %%
x = []
y = []

with open('editedbz.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))

xap = []
yap = []
num = 0

for i in x:
    xap.append(i)
    ind = x.index(i)
    yap.append(y[ind]*10000)
    num = num + 1

#print(xap)
start = min(xap)
end = max(xap)
print(start)
print(end)
print(num)

ave = (max(yap)-min(yap))/num
print(ave)


model = np.poly1d(np.polyfit(x, y, 2)) 

polyline = np.linspace(0, 10, 100)
plt.plot(polyline, model(polyline)) 
plt.plot(x, yap)
plt.xlim([0, .7])
plt.ylim([-0.01,0.025])
plt.title('Bz')
plt.xlabel('Positition (m)')
plt.ylabel('Field Strength (G)')
plt.show()
plt.savefig('Bz')
# Out:
# 0.0
# 0.7
# 162
# 0.0012429987999105598

# %%
x = []
y = []

with open('editeddxdz.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))

xap = []
yap = []
num = 0

for i in x:
    xap.append(i)
    ind = x.index(i)
    yap.append(y[ind])
    num = num + 1

start = min(xap)
end = max(xap)
print(start)
print(end)
print(num)

ave = (max(yap)-min(yap))/num
print(ave)

model = np.poly1d(np.polyfit(x, y, 1)) 

polyline = np.linspace(0, 10, 100)
plt.plot(polyline, model(polyline)) 
plt.plot(x, y)
plt.xlim([0,.7])
plt.title('dbx/dbz gradient')
plt.xlabel('Positition (m)')
plt.ylabel('Field Strength (kg/(m*s^2*A))')
plt.show()
plt.savefig('dbx/dbz')
# Out:
# 0.0
# 0.7
# 162
# 4.969570655721573e-10
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[81], line 43
#      41 plt.ylabel('Field Strength (kg/(m*s^2*A))')
#      42 plt.show()
# ---> 43 plt.savefig('dbx/dbz')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File ~\anaconda3\Lib\site-packages\matplotlib\figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# ...

# %%
x = []
y = []

with open('editeddx.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))

xap = []
yap = []
num = 0

for i in x:
    xap.append(i)
    ind = x.index(i)
    yap.append(y[ind])
    num = num + 1

start = min(xap)
end = max(xap)
print(start)
print(end)
print(num)

ave = (max(yap)-min(yap))/num
print(ave)

model = np.poly1d(np.polyfit(x, y, 1)) 

polyline = np.linspace(0, 10, 100)
plt.plot(polyline, model(polyline)) 
plt.plot(x, y)
plt.xlim([0,.7])
plt.title('dx gradient')
plt.xlabel('Positition (m)')
plt.ylabel('Field Strength (kg/(m*s^2*A))')
plt.show()
plt.savefig('B')
# Out:
# 0.0
# 0.7
# 162
# 3.6639016172799964e-09

# %%
x = []
y = []

with open('editeddy.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))

xap = []
yap = []
num = 0

for i in x:
    xap.append(i)
    ind = x.index(i)
    yap.append(y[ind])
    num = num + 1

start = min(xap)
end = max(xap)
print(start)
print(end)
print(num)

ave = (max(yap)-min(yap))/num
print(ave)

model = np.poly1d(np.polyfit(x, y, 1)) 

polyline = np.linspace(0, 10, 100)
plt.plot(polyline, model(polyline)) 
plt.plot(x, y)
plt.xlim([0,.7])
plt.title('dy gradient')
plt.xlabel('Positition (m)')
plt.ylabel('Field Strength (kg/(m*s^2*A))')
plt.show()
# Out:
# 0.0
# 0.7
# 162
# 3.14061316034085e-09

# %%
x = []
y = []

with open('editeddz.csv', 'r') as file:
    csv_reader = csv.reader(file)
    plots = csv.reader(file, delimiter = ',')
    for _ in range(8):  # Skip first 3 rows
        next(csv_reader)

    for row in plots:
        x.append(float(row[0]))
        y.append(float(row[1]))

xap = []
yap = []
num = 0

for i in x:
    xap.append(i)
    ind = x.index(i)
    yap.append(y[ind])
    num = num + 1

start = min(xap)
end = max(xap)
print(start)
print(end)
print(num)

ave = (max(yap)-min(yap))/num
print(ave)

model = np.poly1d(np.polyfit(x, y, 1)) 

polyline = np.linspace(0, 10, 100)
plt.plot(polyline, model(polyline)) 
plt.plot(x, y)
plt.xlim([0,.7])
plt.title('dz gradient')
plt.xlabel('Positition (m)')
plt.ylabel('Field Strength (kg/(m*s^2*A))')
plt.show()
# Out:
# 0.0
# 0.7
# 162
# 6.394470109694927e-10
